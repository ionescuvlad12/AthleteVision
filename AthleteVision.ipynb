# %% [markdown]
# <a href="https://colab.research.google.com/github/ionescuvlad12/AthleteVision/blob/master/AthleteVision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
# !apt-get install python3.5
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libpython3.5-minimal' for regex 'python3.5'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !pip install -U pip
# !pip install numpy
# Out:
# ...
#      |████████████████████████████████| 1.5MB 8.4MB/s
# ...
#   Found existing installation: pip 19.3.1
#     Uninstalling pip-19.3.1:
#       Successfully uninstalled pip-19.3.1
# ...

# %%
# !git clone https://github.com/akanazawa/human_dynamics
# !zip -r /content/file.zip /content/human_dynamics
# Out:
# Cloning into 'human_dynamics'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 341 (delta 5), reused 1 (delta 0), pack-reused 326
# Receiving objects: 100% (341/341), 131.56 MiB | 22.81 MiB/s, done.
# Resolving deltas: 100% (122/122), done.
#   adding: content/human_dynamics/ (stored 0%)
#   adding: content/human_dynamics/src/ (stored 0%)
#   adding: content/human_dynamics/src/data_loader_sequence.py (deflated 76%)
#   adding: content/human_dynamics/src/tf_smpl/ (stored 0%)
#   adding: content/human_dynamics/src/tf_smpl/smpl_faces.npy (deflated 64%)
#   adding: content/human_dynamics/src/tf_smpl/batch_lbs.py (deflated 65%)
#   adding: content/human_dynamics/src/tf_smpl/projection.py (deflated 62%)
#   adding: content/human_dynamics/src/tf_smpl/batch_smpl.py (deflated 68%)
#   adding: content/human_dynamics/src/tf_smpl/__init__.py (stored 0%)
# ...

# %%
#os.chdir("human_dynamics")
# !pip install -r requirements.txt --verbose
# Out:
# Using pip 20.2.2 from /usr/local/lib/python3.6/dist-packages/pip (python 3.6)
# Non-user install because site-packages writeable
# Created temporary directory: /tmp/pip-ephem-wheel-cache-26gqqr4l
# Created temporary directory: /tmp/pip-req-tracker-ofqwu76r
# Initialized build tracking at /tmp/pip-req-tracker-ofqwu76r
# Created build tracker: /tmp/pip-req-tracker-ofqwu76r
# Entered build tracker: /tmp/pip-req-tracker-ofqwu76r
# Created temporary directory: /tmp/pip-install-_sw9pea6
# ...
# 1 location(s) to search for versions of absl-py:
# * https://pypi.org/simple/absl-py/
# Fetching project page and analyzing links: https://pypi.org/simple/absl-py/
# Getting page https://pypi.org/simple/absl-py/
# Found index url https://pypi.org/simple
# Looking up "https://pypi.org/simple/absl-py/" in the cache
# Request header has "max_age" as 0, cache bypassed
# Starting new HTTPS connection (1): pypi.org:443
# https://pypi.org:443 "GET /simple/absl-py/ HTTP/1.1" 304 0
# ...
